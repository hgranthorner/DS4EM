# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline 
#this line above prepares IPython notebook for working with matplotlib

# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().

import numpy as np # imports a fast numerical programming library
import scipy as sp #imports stats functions, amongst other things
import pandas as pd #lets us handle data as dataframes

#When we want to start automating behavior, enable some of that good 'ol selenium
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys

#sets up pandas table display
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns #sets up styles and gives us more plotting options

#Allows access to webpages and html code
import requests

#format the outpout of the html into something more readable
from bs4 import BeautifulSoup
from lxml import html

# %%
#Define our login credentials
payload = {
    "username": "<USER NAME>",
    "password": "<PASSWORD",
    "authenticityToken": "<CSRF_TOKEN>"
}

# %%
session_requests = requests.session()

# %%
#Log into Urjanet and return the authenticity key
urj_login_url = "https://portal.urjanet.net/login"
result = session_requests.get(urj_login_url)

tree = html.fromstring(result.text)
auth_token = list(set(tree.xpath("//input[@name='authenticityToken']/@value")))[0]

# %%
soup = BeautifulSoup(result.content,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Login</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/public/stylesheets/bootstrap-3.2.0/bootstrap.css" rel="stylesheet"/>
# <link href="/public/stylesheets/urjanet.css" rel="stylesheet"/>
# <script src="/public/javascripts/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/public/javascripts/bootstrap-3.2.0.js" type="text/javascript"></script>
# <script async="async" defer="defer" src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#     body {
#       padding-top: 12%;
#       background: url(/public/images/bg-Lasers.svg) no-repeat center center fixed;
#       background-color: #3A389F;
#       background-size: cover;
#     }
#
#     #main {
#       padding: 5em 8em;
#       border-radius: 4px;
#     }
#
#     #topspacer {
#       height: 80px;
#       height: 10%;
#       width: 100%;
#     }
#
#     #bgoverlay{
# ...

# %%
result = session_requests.post(
    login_url,
    data = payload,
    headers = dict(referer = login_url)
)

# %%
#Scrape the content from the site
url = '"https://portal.urjanet.net/login'
request = session_requests.get(url)
noodle_soup = BeautifulSoup(request.content, 'lxml')
invoice_table = noodle_soup.find_all('tr')[0]
df = pd.read_html(str(invoice_table))[0]
df

# %%
# When we eventualy get our automation on
#driver = webdriver.Firefox()
#driver.get("http://www.youradress.org")#put here the adress of your page
#elem = driver.find_elements_by_xpath("//*[@type='submit']")#put here the content you have put in Notepad, ie the XPath
#print(elem .get_attribute("class"))
#driver.close()
